# %%
import pandas as pd
import numpy as np
import os
import json
import requests
import urllib
import re
import sys
from glob import glob

# %%
TOP_PATH = os.environ['PWD']

# %%
# %load_ext autoreload
# %autoreload 2

# %%
sys.path.append('/Users/tevansbarton/AAASideProjects/GMDraftTendencies/config')
sys.path.append('/Users/tevansbarton/AAASideProjects/GMDraftTendencies/src')
sys.path.append('/Users/tevansbarton/AAASideProjects/GMDraftTendencies/src/data')
sys.path.append('/Users/tevansbarton/AAASideProjects/GMDraftTendencies/src/processing')

# %%
import etl
import processing

# %%
# Read in data if need be

# with open(TOP_PATH + '/config/data-params.json') as fh:
#     data_cfg = json.load(fh)
# etl.get_data(**data_cfg)

# %%
raw_draft_2014 = pd.read_csv(TOP_PATH + '/data/raw/DRAFT_2014.csv')

# %%
raw_draft_2014.describe().T
# Out:
#                   count         mean          std     min      25%     50%  \
# Rnd               256.0     4.160156     1.986655     1.0     2.75     4.0
# Pick              256.0   128.500000    74.045031     1.0    64.75   128.5
# Age               256.0    22.472656     0.924203    20.0    22.00    22.0
# To                252.0  2017.246032     1.915283  2014.0  2016.00  2018.0
# AP1               256.0     0.050781     0.444310     0.0     0.00     0.0
# PB                256.0     0.281250     0.973673     0.0     0.00     0.0
# St                256.0     1.574219     2.039406     0.0     0.00     0.0
# Approx Val CarAV  252.0    13.464286    15.401231    -1.0     1.00     7.0
# Approx Val DrAV   237.0    11.590717    14.267912    -1.0     1.00     6.0
# G                 252.0    45.130952    30.683494     0.0    15.00    45.0
# Passing Cmp       252.0    22.353175   175.433914     0.0     0.00     0.0
# Passing Att       252.0    35.829365   280.531195     0.0     0.00     0.0
# Passing Yds       252.0   249.829365  1930.919629     0.0     0.00     0.0
# Passing TD        252.0     1.448413    11.668108     0.0     0.00     0.0
# Passing Int       252.0     0.853175     6.515555     0.0     0.00     0.0
# Rushing Att       252.0    27.511905   122.612351     0.0     0.00     0.0
# Rushing Yds       252.0   110.353175   497.108642   -12.0     0.00     0.0
# Rushing TD        252.0     0.746032     3.625796     0.0     0.00     0.0
# Receiving Rec     252.0    28.392857    85.271913     0.0     0.00     0.0
# Receiving Yds     252.0   337.603175  1093.469886    -9.0     0.00     0.0
# Receiving TD      252.0     2.253968     7.518303     0.0     0.00     0.0
# Solo              148.0    79.439189   102.699431     1.0     5.00    33.5
# Int                55.0     3.981818     4.174397     1.0     1.00     2.0
# Sk                 73.0     8.732877    13.061309     0.5     1.00     4.0
# YEAR              256.0  2014.000000     0.000000  2014.0  2014.00  2014.0
#
#                       75%      max
# Rnd                  6.00      7.0
# Pick               192.25    256.0
# Age                 23.00     26.0
# To                2019.00   2019.0
# AP1                  0.00      5.0
# PB                   0.00      6.0
# St                   3.00      6.0
# Approx Val CarAV    22.25     80.0
# Approx Val DrAV     18.00     80.0
# G                   74.25     96.0
# Passing Cmp          0.00   2120.0
# Passing Att          0.00   3313.0
# Passing Yds          0.00  22793.0
# Passing TD           0.00    143.0
# Passing Int          0.00     75.0
# Rushing Att          0.00   1072.0
# Rushing Yds          0.00   4370.0
# Rushing TD           0.00     32.0
# Receiving Rec        0.00    564.0
# Receiving Yds        0.00   7260.0
# Receiving TD         0.00     48.0
# Solo               115.25    446.0
# Int                  5.00     18.0
# Sk                   8.50     72.0
# YEAR              2014.00   2014.0
