# %%
import pandas as pd
import numpy as np
import os
import json
import requests
import urllib
import re
import sys
from glob import glob

# %%
TOP_PATH = os.environ['PWD']

# %%
# %load_ext autoreload
# %autoreload 2

# %%
sys.path.append('/Users/tevansbarton/AAASideProjects/GMDraftTendencies/config')
sys.path.append('/Users/tevansbarton/AAASideProjects/GMDraftTendencies/src')
sys.path.append('/Users/tevansbarton/AAASideProjects/GMDraftTendencies/src/data')
sys.path.append('/Users/tevansbarton/AAASideProjects/GMDraftTendencies/src/processing')

# %%
import etl
import processing

# %%
# Read in data if need be

# with open(TOP_PATH + '/config/data-params.json') as fh:
#     data_cfg = json.load(fh)
# etl.get_data(**data_cfg)

# %%
raw_draft_2018 = pd.read_csv(TOP_PATH + '/data/raw/DRAFT_2018.csv')

# %%
raw_draft_2018.describe().T
# Out:
#                   count         mean         std     min      25%     50%  \
# Rnd               256.0     4.167969    1.980075     1.0     2.75     4.0
# Pick              256.0   128.500000   74.045031     1.0    64.75   128.5
# Age               256.0    22.226562    0.939043    20.0    22.00    22.0
# To                233.0  2018.935622    0.245953  2018.0  2019.00  2019.0
# AP1               256.0     0.027344    0.185859     0.0     0.00     0.0
# PB                256.0     0.062500    0.258199     0.0     0.00     0.0
# St                256.0     0.535156    0.755849     0.0     0.00     0.0
# Approx Val CarAV  233.0     5.815451    5.683106     0.0     2.00     4.0
# Approx Val DrAV   223.0     5.834081    5.681827    -1.0     2.00     4.0
# G                 233.0    22.502146    8.776990     1.0    16.00    25.0
# Passing Cmp       233.0    10.519313   67.735037     0.0     0.00     0.0
# Passing Att       233.0    17.605150  113.196040     0.0     0.00     0.0
# Passing Yds       233.0   120.493562  790.852923     0.0     0.00     0.0
# Passing TD        233.0     0.781116    5.306079     0.0     0.00     0.0
# Passing Int       233.0     0.540773    3.545190     0.0     0.00     0.0
# Rushing Att       233.0    17.909871   67.326377     0.0     0.00     0.0
# Rushing Yds       233.0    82.025751  319.853117    -2.0     0.00     0.0
# Rushing TD        233.0     0.609442    2.449014     0.0     0.00     0.0
# Receiving Rec     233.0    11.746781   27.040205     0.0     0.00     0.0
# Receiving Yds     233.0   133.274678  331.871408    -5.0     0.00     0.0
# Receiving TD      233.0     0.785408    2.271706     0.0     0.00     0.0
# Solo              149.0    33.657718   40.637949     1.0     5.00    17.0
# Int                33.0     2.545455    1.954017     1.0     1.00     2.0
# Sk                 61.0     3.614754    3.387961     0.5     1.50     2.5
# YEAR              256.0  2018.000000    0.000000  2018.0  2018.00  2018.0
#
#                       75%     max
# Rnd                  6.00     7.0
# Pick               192.25   256.0
# Age                 23.00    26.0
# To                2019.00  2019.0
# AP1                  0.00     2.0
# PB                   0.00     2.0
# St                   1.00     2.0
# Approx Val CarAV     8.00    33.0
# Approx Val DrAV      8.00    33.0
# G                   30.00    32.0
# Passing Cmp          0.00   627.0
# Passing Att          0.00  1020.0
# Passing Yds          0.00  7552.0
# Passing TD           0.00    49.0
# Passing Int          0.00    35.0
# Rushing Att          0.00   490.0
# Rushing Yds          0.00  2490.0
# Rushing TD           0.00    17.0
# Receiving Rec        5.00   143.0
# Receiving Yds       38.00  1963.0
# Receiving TD         0.00    17.0
# Solo                47.00   182.0
# Int                  3.00     7.0
# Sk                   5.00    14.5
# YEAR              2018.00  2018.0
