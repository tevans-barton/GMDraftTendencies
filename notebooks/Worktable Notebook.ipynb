# %%
import pandas as pd
import numpy as np
import os
import json
import requests
import urllib
import re
import sys
from glob import glob
from fuzzywuzzy import fuzz

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sys.path.append('/Users/tevansbarton/AAASideProjects/GMDraftTendencies/config')
sys.path.append('/Users/tevansbarton/AAASideProjects/GMDraftTendencies/src')
sys.path.append('/Users/tevansbarton/AAASideProjects/GMDraftTendencies/src/data')
sys.path.append('/Users/tevansbarton/AAASideProjects/GMDraftTendencies/src/processing')

# %%
import etl
import processing

# %%
TOP_PATH = os.environ['PWD']

# %%
with open(TOP_PATH + '/config/data-params.json') as fh:
    data_cfg = json.load(fh)

# %%
#etl.get_data(**data_cfg)

# %%
draft_2019 = pd.read_csv(TOP_PATH + '/data/raw/DRAFT_2019.csv')

# %%
full_df = processing.combine_and_clean_all_drafts()
# Out:
# Error cleaning college info for 2020 possibly due to draft not having happened yet
# Problem Merging COMBINE_2020.csv and DRAFT_2020.csv possibly due to lack of draft information

# %%
comb_college = set(full_df['College'])
draft_college = set(full_df['College/Univ'])

# %%
full_df[(full_df['College'] != full_df['College/Univ']) & ~full_df['College'].isnull()][['YEAR','Player', 'College/Univ', 'Pos', 'College', 'POS']].sort_values('Player')
# Out:
#       YEAR                Player               College/Univ Pos  \
# 601   2012           Akiem Hicks                        NaN  DE
# 681   2012           Asa Jackson                        NaN  DB
# 597   2012          Bill Bentley                        NaN  DB
# 396   2011        Brandon Burton              Southern Utah  DB
# 1634  2016      Brandon Williams                  Texas A&M  CB
# 436   2011    Caleb Schlauderaff              Southern Utah   G
# 370   2011          Cecil Shorts                Mount Union  WR
# 1271  2014          Charles Leno                Boise State   T
# 124   2010           Clay Harbor          SW Missouri State  TE
# 2388  2019            David Long                   Michigan  CB
# 2497  2019            David Long              West Virginia  LB
# 1322  2015  Dorial Green-Beckham                   Oklahoma  WR
# 170   2010          Fendi Onobun                    Arizona  TE
# 683   2012         Greg Zuerlein                        NaN   K
# 1356  2015         Hroniss Grasu                     Oregon   C
# 459   2011     Jacquian Williams              South Florida  LB
# 2285  2018        Jordan Mailata                        NaN   T
# 2263  2018         Jordan Thomas          Mississippi State  TE
# 1538  2015           Josh Furman             Oklahoma State  DB
# 1288  2015           Kevin White              West Virginia  WR
# 970   2013         Khalid Wooten                     Nevada  DB
# 622   2012        Ladarius Green                        NaN  TE
# 423   2011       Lawrence Wilson  Central Connecticut State  LB
# 416   2011             Lee Smith                  Tennessee  TE
# 713   2012          Matt McCants                        NaN   T
# 1465  2015       Michael Bennett                 Ohio State  DT
# 1011  2013         Michael Bowie                        NaN   T
# 2081  2018           Mike Hughes            Central Florida  CB
# 1723  2016     Moritz Boehringer                        NaN  WR
# 1502  2015   Rakeem Nunez-Roches       Southern Mississippi  DT
# 716   2012        Robert Griffin                     Baylor  OL
# 514   2012        Robert Griffin                     Baylor  QB
# 384   2011        Roc Carmichael              Virginia Tech  DB
# 969   2013          Ryan Griffin                Connecticut  TE
# 972   2013           Ryan Jensen                        NaN   T
# 493   2011        Stephen Burton              Long Beach CC  WR
# 806   2013        Tank Carradine              Florida State  DE
# 508   2011       Tommie Campbell                 Pittsburgh  DB
# 337   2011         Vincent Brown            San Diego State  WR
#
#                     College  POS
# 601                  Regina   DT
# 681                Cal Poly   CB
# 597                Colorado   CB
# 396                    Utah   CB
# 1634      Southern Illinois  OLB
# 436                    Utah   OG
# 370                Missouri   WR
# 1271   North Carolina State   OG
# 124          Missouri State   FB
# 2388          West Virginia   LB
# 2497               Michigan   CB
# 1322               Missouri   WR
# 170                 Houston   TE
# 683        Missouri Western    K
# 1356          Virginia Tech    C
# 459              Texas Tech  OLB
# 2285             No College   DT
# 2263               Oklahoma   CB
# 1538               Michigan  OLB
# 1288        Texas Christian   CB
# 970                 Indiana   CB
# 622     Louisiana-Lafayette   TE
# 423             Connecticut  OLB
# 416                Marshall   TE
# 713      Alabama-Birmingham   OT
# 1465                Georgia   WR
# 1011     Northeastern State   OT
# 2081                   UNLV   DT
# 1723        Schwabisch Hall   WR
# 1502               Nebraska   DT
# 716            Kansas State   OG
# 514            Kansas State   OG
# 384                 Clemson   CB
# 969                  Tulane   QB
# 972   Colorado State-Pueblo   OG
# 493          West Texas A&M   WR
# 806           Virginia Tech   DE
# 508              California   FS
# 337                   Miami   WR

# %%
full_df[['Player', 'College/Univ', 'Pos', 'College', 'POS']]
# Out:
#                 Player    College/Univ Pos         College  POS
# 0         Sam Bradford        Oklahoma  QB        Oklahoma   QB
# 1        Ndamukong Suh        Nebraska  DT        Nebraska   DT
# 2         Gerald McCoy        Oklahoma  DT        Oklahoma   DT
# 3       Trent Williams        Oklahoma   T        Oklahoma   OT
# 4           Eric Berry       Tennessee  DB       Tennessee   FS
# ...                ...             ...  ..             ...  ...
# 2560    Austin Cutting       Air Force  LS       Air Force   LS
# 2561      Dakota Allen      Texas Tech  LB      Texas Tech   LB
# 2562       Ken Webster     Mississippi  CB     Mississippi   CB
# 2563  Jordan Brailford  Oklahoma State  DE  Oklahoma State  EDG
# 2564      Caleb Wilson            UCLA  TE            UCLA   TE
#
# [2565 rows x 5 columns]

# %% [markdown]
# 2544 is the number
